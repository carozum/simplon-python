# %% [markdown]
# # Visualisation graphique : Seaborn

# %% [markdown]
# ## Un 1er jeu de données

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd
data = pd.read_csv('Data/Demographic-Data.csv')
data.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# ## Introduction à Seaborn

# %% [markdown]
# *Seaborn* est un package très puissant construit à partir de matplotlib et qui permet de visualiser les informations de différentes manières.
#
# Pour voir les différentes visualisations possibles, regrader la page https://seaborn.pydata.org/examples/index.html ou chercher *galerie Seaborn* sur internet

# %%
import seaborn as sns

# %% [markdown]
# ## Histogrammes = distribution

# %%
vis1 = sns.displot(data['Internet users'], kde=False)

# %%
vis1 = sns.displot(data['Internet users'], bins=10)

# %% [markdown]
# ## Boxplots

# %%
import matplotlib.pyplot as plt
vis2 = sns.boxplot(data=data, x='Income Group', y='Birth rate')
plt.xticks(rotation=70);

# %% [markdown]
# ## Stripplot

# %%
# équivalent du scatter plot pour des variables catégories
vis3 = sns.stripplot(x='Income Group', y='Internet users', data = data)

# %% [markdown]
# ## Combinaison de graphes dans une figure

# %%
fig, axes = plt.subplots(1,2,figsize=(14,6))
fig.subplots_adjust(wspace = 0.3)

ax1 = sns.histplot(data['Internet users'], bins=10, ax = axes[0])
ax1.set_title('Histogramme')

ax2 = sns.boxplot(data=data, x='Income Group', y='Birth rate', ax = axes[1])
ax2.set_title('Boîte')

plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# ## Modèles linéaires

# %%
vis3 = sns.lmplot(data=data, x='Internet users', y='Birth rate')

# %%
vis3 = sns.lmplot(data=data, x='Internet users', y='Birth rate',fit_reg=False)

# %%
vis3 = sns.lmplot(data=data, x='Internet users', y='Birth rate', fit_reg = False, hue='Income Group')

# %%
vis3 = sns.lmplot(data=data, x='Internet users', y='Birth rate', fit_reg = False, hue='Income Group', height = 8)

# %%
# on peut ajouter des options d'affichage de matplotlib, il faut utiliser les dictionnaires {scatter,lines}_kws
# (kws = key words arguments)
vis3 = sns.lmplot(data=data, x='Internet users', y='Birth rate',
                  fit_reg = False,
                  hue='Income Group',
                  height = 10,
                  scatter_kws ={'s':100})

# %%
# en utilisant pandas
data.plot( x='Internet users', y='Birth rate', kind="scatter", s=19 )
# Out:
# <AxesSubplot:xlabel='Internet users', ylabel='Birth rate'>

# %% [markdown]
# ## Nouveau jeu de données

# %%
movies = pd.read_csv('Data/Movie-Ratings.csv')
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
# on peut changer le nom de colonnes par des noms plus faciles à utiliser
# (moins longs, sans espaces ni caractère spéciaux)
movies.columns = ['Film', 'Genre', 'CriticRatings', 'AudienceRatings', 'Budget', 'Year']
movies.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  Budget  \
# 0  (500) Days of Summer      Comedy             87               81       8
# 1            10,000 B.C.  Adventure              9               44     105
# 2             12 Rounds      Action             30               52      20
# 3              127 Hours  Adventure             93               84      18
# 4              17 Again      Comedy             55               70      20
#
#    Year
# 0  2009
# 1  2008
# 2  2009
# 3  2010
# 4  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRatings  AudienceRatings      Budget         Year
# count     559.000000       559.000000  559.000000   559.000000
# mean       47.309481        58.744186   50.236136  2009.152057
# std        26.413091        16.826887   48.731817     1.362632
# min         0.000000         0.000000    0.000000  2007.000000
# 25%        25.000000        47.000000   20.000000  2008.000000
# 50%        46.000000        58.000000   35.000000  2009.000000
# 75%        70.000000        72.000000   65.000000  2010.000000
# max        97.000000        96.000000  300.000000  2011.000000

# %% [markdown]
# ### Type de données Category

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
# l'année peut être une variable catégoriques
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    category
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(2), int64(3), object(1)
# memory usage: 19.2+ KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.Year.cat.categories
# Out:
# Int64Index([2007, 2008, 2009, 2010, 2011], dtype='int64')

# %%
movies.Genre.describe()
# Out:
# count        559
# unique         7
# top       Comedy
# freq         172
# Name: Genre, dtype: object

# %%
movies.describe()
# Out:
#        CriticRatings  AudienceRatings      Budget
# count     559.000000       559.000000  559.000000
# mean       47.309481        58.744186   50.236136
# std        26.413091        16.826887   48.731817
# min         0.000000         0.000000    0.000000
# 25%        25.000000        47.000000   20.000000
# 50%        46.000000        58.000000   35.000000
# 75%        70.000000        72.000000   65.000000
# max        97.000000        96.000000  300.000000

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## JointPlots

# %%
vis4 = sns.jointplot(data = movies, x = 'CriticRatings', y = 'AudienceRatings')

# %%
vis4 = sns.jointplot(data = movies, x = 'CriticRatings', y = 'AudienceRatings', kind = 'hex')

# %%
vis4 = sns.jointplot(data = movies, x = 'CriticRatings', y = 'AudienceRatings', kind = 'reg')

# %%
vis4 = sns.jointplot(data = movies, x = 'CriticRatings', y = 'AudienceRatings', kind = 'kde')

# %% [markdown]
# ## Histogrammes empilés

# %% [markdown]
# Les histogrammes empilés (*stacked histograms*) consistent à empiler chaque colonne l'une sur l'autre.

# %%
# on peut superposer des histogrammes, mais ce n'est pas exactement ce qu'on veut...
plt.hist(movies[movies.Genre=='Action'].Budget, bins=12)
plt.hist(movies[movies.Genre=='Drama'].Budget, bins=12)
plt.hist(movies[movies.Genre=='Thriller'].Budget, bins=12)
plt.show()

# %%
# on peut mettre côte à côte sur un même graphique des histogrammes, mais ce n'est toujours pas ce qu'on veut...
plt.hist([movies[movies.Genre=='Action'].Budget,
          movies[movies.Genre=='Drama'].Budget,
          movies[movies.Genre=='Thriller'].Budget],
         bins=12)
plt.show()

# %%
movies
movies[['Film','Genre']]
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
# une solution : l'option stacked
plt.hist([movies[movies.Genre=='Action'].Budget,
          movies[movies.Genre=='Drama'].Budget,
          movies[movies.Genre=='Thriller'].Budget],
         bins=15,
        stacked = True)
plt.show()

# %% [markdown]
# ### Petit exercice

# %% [markdown]
# Construire un histogramme empilé avec tous les genres présents dans le jeu de données.

# %%
#sns.displot()

# %%
l = list()
labels = list()
for genre in movies.Genre.cat.categories:
    l.append(movies[movies.Genre == genre].Budget)
    labels.append(genre)
plt.hist(l,labels=labels,stacked = True, bins=15);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-5d8b12b9e4a0> in <module>
#       4     l.append(movies[movies.Genre == genre].Budget)
#       5     labels.append(genre)
# ----> 6 plt.hist(l,labels=labels,stacked = True, bins=15);
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2851         orientation='vertical', rwidth=None, log=False, color=None,
#    2852         label=None, stacked=False, *, data=None, **kwargs):
# -> 2853     return gca().hist(
#    2854         x, bins=bins, range=range, density=density, weights=weights,
#    2855         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6909             if patch:
#    6910                 p = patch[0]
# -> 6911                 p.update(kwargs)
#    6912                 if lbl is not None:
#    6913                     p.set_label(lbl)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/artist.py in update(self, props)
#    1060                     func = getattr(self, f"set_{k}", None)
#    1061                     if not callable(func):
# -> 1062                         raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                              f"has no property {k!r}")
#    1064                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'labels'

# %% [markdown]
# ## Kernel Density Estimates (KDE) plot

# %%
vis5 = sns.kdeplot(data=movies, x="CriticRatings", y="AudienceRatings")

# %%
vis5 = sns.kdeplot(x=movies.CriticRatings, y=movies.AudienceRatings, fill = True)

# %%
vis5 = sns.kdeplot(x=movies.CriticRatings, y=movies.AudienceRatings,
                   fill = True, thresh=0.05, cmap='Reds')

# %%
vis5 = sns.kdeplot(x=movies.CriticRatings, y=movies.AudienceRatings,
                   cmap='Reds')

# %% [markdown]
# ## Diagrammes en violon

# %%
vis6 = sns.violinplot(data=movies, x='Genre', y='CriticRatings')

# %%
fig, axes = plt.subplots(1,2,figsize=(14,6))
fig.subplots_adjust(wspace = 0.3)
ax1 = sns.violinplot(data=movies, x='Genre', y='CriticRatings', ax = axes[0])
ax2 = sns.boxplot(data=movies, x='Genre', y='CriticRatings', ax = axes[1])
plt.show()

# %% [markdown]
# ### Exercice

# %% [markdown]
# - Filtrer les données uniquement pour le genre Drame
# - Afficher une figure avec les 2 graphiques (violon et boîte à moustaches) pour les notes des critiques en fonction des années
# - Comparer les deux types de graphiques pour voir leur intérêt

# %%
filtre = movies.Genre == 'Drama'
drama = movies[filtre]

fig, axes = plt.subplots(1,2,figsize=(14,6))
fig.subplots_adjust(wspace = 0.3)
ax1 = sns.boxplot(data=drama, x='Year', y='AudienceRatings', ax = axes[0])
ax2 = sns.boxplot(data=drama, x='Year', y='CriticRatings', ax = axes[1])
plt.show()

# %%
filtre = movies.Genre == 'Horror'
horror = movies[filtre]

fig, axes = plt.subplots(1,2,figsize=(14,6))
fig.subplots_adjust(wspace = 0.3)
ax1 = sns.boxplot(data=horror, x='Year', y='AudienceRatings', ax = axes[0])
ax2 = sns.boxplot(data=horror, x='Year', y='CriticRatings', ax = axes[1])
plt.show()

# %% [markdown]
# ## Facet Grid

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = {'s':50, 'linewidth':0.5, 'edgecolor':'black'}
#kws = dict(s=50, linewidth=0.5, edgecolor='black')          
g = g.map(plt.scatter, 'CriticRatings', 'AudienceRatings', **kws)

# %%
# on peut généraliser à tous les types de graphiques
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(bins=12)
g = g.map(plt.hist, 'CriticRatings', **kws)

# %%
# on peut ajouter les diagonales par exemple et fixer les échelles des axes
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')

kws = {'s':50, 'linewidth':0.5, 'edgecolor':'black'} #kws = dict(s=50, linewidth=0.5, edgecolor=black')

g = g.map(plt.scatter, 'CriticRatings', 'AudienceRatings', **kws)

g.set(xlim=(0,100), ylim=(0,100))

for ax in g.axes.flat:
    ax.plot((0,100),(0,100), c='gray', ls='--')
    
g.add_legend()

# %% [markdown]
# ## Une belle figure : un dashboard (tableau de bord)

# %%
sns.set_style('white') #pour changer le fond, essayer avec 'darkgrid' par exemple pour voir la différence

f,axes = plt.subplots(2,2,figsize =(15,15))

# Axes 1
k1 = sns.kdeplot(data=movies, x="Budget", y="AudienceRatings", ax = axes[0,0])

# Axes 2
k2 = sns.kdeplot(data=movies, x="Budget", y="CriticRatings", ax = axes[0,1])

# Axes 3
v = sns.violinplot(data = movies, x ='Year', y='CriticRatings', ax = axes[1,0])

# Axes 4
k3 = sns.kdeplot(data=movies, x="CriticRatings", y="AudienceRatings", cmap='Reds', ax= axes[1,1])
k3 = sns.kdeplot(data=movies, x="CriticRatings", y="AudienceRatings",
                   fill = True, thresh=0.05, cmap='Reds', ax= axes[1,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
plt.show()

# %%
sns.set_style('darkgrid', {'axes.facecolor' : 'black'})

f,axes = plt.subplots(2,2,figsize =(15,15))

# Axes 1
k1 = sns.kdeplot(data=movies, x="Budget", y="AudienceRatings", cmap='cool', ax = axes[0,0])
k1b = sns.kdeplot(data=movies, x="Budget", y="AudienceRatings",
                 fill = True, thresh=0.05, cmap='inferno', ax = axes[0,0])

# Axes 2
k2 = sns.kdeplot(data=movies, x="Budget", y="CriticRatings", cmap='Blues', ax = axes[0,1])
k2b = sns.kdeplot(data=movies, x="Budget", y="CriticRatings", 
                 fill = True, thresh=0.05, cmap='Greens', ax = axes[0,1])

# Axes 3
v = sns.violinplot(data = movies, x ='Year', y='CriticRatings', hue='Year', ax = axes[1,0],
                  palette = 'YlOrRd', legend=False)

# Axes 4
k3 = sns.kdeplot(data=movies, x="CriticRatings", y="AudienceRatings", cmap='gist_gray_r', ax= axes[1,1])
k3b = sns.kdeplot(data=movies, x="CriticRatings", y="AudienceRatings",
                   fill = True, thresh=0.05, cmap='Blues', ax= axes[1,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
plt.show()

# %% [markdown]
# ### Exercice

# %% [markdown]
# Créer votre propre dashboard avec 6 graphiques différents à partir des tous les exemples vus dans ce notebook.
